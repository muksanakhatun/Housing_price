# %% [markdown]
# ### HOUSING DATASET
# - id :a notation for a house   ,,                         date: Date house was sold
# - price: Price is prediction target   ,,                  bedrooms: Number of Bedrooms/House
# - bathrooms: Number of bathrooms/bedrooms  ,,             sqft_living: square footage of the home
# - sqft_lot: square footage of the lot     ,,              floors :Total floors (levels) in house
# - waterfront :House which has a view to a waterfront ,,   view: Has been viewed
# - condition :How good the condition is Overall      ,,    grade: overall grade given to the housing unit, based on King County grading system
# - sqft_above :square footage of house apart from basement ,, sqft_basement: square footage of the basement
# - yr_built :Built Year                     ,,             yr_renovated :Year when house was renovated
# - zipcode:zip code                        ,,             lat: Latitude coordinate
# - long: Longitude coordinate
#
#
# #### MUKSANA KHATUN
# 7/10/2022

# %% [markdown]
# ##  Importing AND displaying the Data
# Load the csv

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
housing = pd.read_csv('housing_price.csv')
housing.sample(1)
# Out:
#                      date     price  bedrooms  bathrooms  sqft_living  \
# 2777  2014-06-18 00:00:00  410000.0       4.0        2.0         1970
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# 2777     10500     1.0           0     0          3        1820
#
#       sqft_basement  yr_built  yr_renovated             street    city  \
# 2777            150      1961          2004  13666 17th Ave SW  Burien
#
#       statezip country
# 2777  WA 98166     USA

# %% [markdown]
# - imported all the libraried needed
# - we use the method ***SAMPLE*** to display the RANDOM sample 1 columns of the dataframe.

# %%
def f(row):
    if row['yr_renovated'] == 0 :
        val = 'no'
    else:
        val = 'yes'
    return val
housing['renovated'] = housing.apply(f, axis=1)

# %%
housing['age']= 2014 - housing['yr_built']

# %%
housing['price_sqliving']= round((housing['price']/ housing['sqft_living']) , 2)

# %% [markdown]
# #### Added **3 more columns** to the dataframe

# %%
housing.sample(2)
# Out:
#                      date     price  bedrooms  bathrooms  sqft_living  \
# 4388  2014-05-15 00:00:00  300000.0       3.0        2.0         1510
# 1367  2014-05-27 00:00:00  295832.0       5.0        1.0         1410
#
#       sqft_lot  floors  waterfront  view  condition  ...  sqft_basement  \
# 4388      7066     1.0           0     2          3  ...            280
# 1367      6400     1.0           0     0          5  ...            450
#
#       yr_built  yr_renovated               street        city  statezip  \
# 4388      1973          2013  10516 Victory Ln NE     Seattle  WA 98125
# 1367      1955             0       20208 1st Pl S  Des Moines  WA 98198
#
#      country renovated age  price_sqliving
# 4388     USA       yes  41          198.68
# 1367     USA        no  59          209.81
#
# [2 rows x 21 columns]

# %%
housing.describe()
# Out:
#               price     bedrooms    bathrooms   sqft_living      sqft_lot  \
# count  4.600000e+03  4600.000000  4600.000000   4600.000000  4.600000e+03
# mean   5.519630e+05     3.400870     2.160815   2139.346957  1.485252e+04
# std    5.638347e+05     0.908848     0.783781    963.206916  3.588444e+04
# min    0.000000e+00     0.000000     0.000000    370.000000  6.380000e+02
# 25%    3.228750e+05     3.000000     1.750000   1460.000000  5.000750e+03
# 50%    4.609435e+05     3.000000     2.250000   1980.000000  7.683000e+03
# 75%    6.549625e+05     4.000000     2.500000   2620.000000  1.100125e+04
# max    2.659000e+07     9.000000     8.000000  13540.000000  1.074218e+06
#
#             floors   waterfront         view    condition   sqft_above  \
# count  4600.000000  4600.000000  4600.000000  4600.000000  4600.000000
# mean      1.512065     0.007174     0.240652     3.451739  1827.265435
# std       0.538288     0.084404     0.778405     0.677230   862.168977
# min       1.000000     0.000000     0.000000     1.000000   370.000000
# 25%       1.000000     0.000000     0.000000     3.000000  1190.000000
# 50%       1.500000     0.000000     0.000000     3.000000  1590.000000
# 75%       2.000000     0.000000     0.000000     4.000000  2300.000000
# max       3.500000     1.000000     4.000000     5.000000  9410.000000
#
#        sqft_basement     yr_built  yr_renovated          age  price_sqliving
# count    4600.000000  4600.000000   4600.000000  4600.000000     4600.000000
# mean      312.081522  1970.786304    808.608261    43.213696      265.876209
# std       464.137228    29.731848    979.414536    29.731848      357.503362
# min         0.000000  1900.000000      0.000000     0.000000        0.000000
# 25%         0.000000  1951.000000      0.000000    17.000000      180.817500
# 50%         0.000000  1976.000000      0.000000    38.000000      243.855000
# 75%       610.000000  1997.000000   1999.000000    63.000000      314.840000
# max      4820.000000  2014.000000   2014.000000   114.000000    22533.900000

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4600 entries, 0 to 4599
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   date            4600 non-null   object
#  1   price           4600 non-null   float64
#  2   bedrooms        4600 non-null   float64
#  3   bathrooms       4600 non-null   float64
#  4   sqft_living     4600 non-null   int64
#  5   sqft_lot        4600 non-null   int64
#  6   floors          4600 non-null   float64
#  7   waterfront      4600 non-null   int64
#  8   view            4600 non-null   int64
#  9   condition       4600 non-null   int64
#  10  sqft_above      4600 non-null   int64
#  11  sqft_basement   4600 non-null   int64
#  12  yr_built        4600 non-null   int64
#  13  yr_renovated    4600 non-null   int64
#  14  street          4600 non-null   object
#  15  city            4600 non-null   object
#  16  statezip        4600 non-null   object
#  17  country         4600 non-null   object
#  18  renovated       4600 non-null   object
#  19  age             4600 non-null   int64
#  20  price_sqliving  4600 non-null   float64
# dtypes: float64(5), int64(10), object(6)
# memory usage: 754.8+ KB

# %% [markdown]
# ### Rplacing missing values
# #### Finding the correlation between price and other variables

# %%
plt.figure(figsize = (15,6))
sns.boxplot( x= 'price' , data= housing)
# Out:
# <AxesSubplot:xlabel='price'>

# %%
plt.figure(figsize = (10,5))
sns.boxplot( x= 'price_sqliving' , data= housing)
# Out:
# <AxesSubplot:xlabel='price_sqliving'>

# %% [markdown]
# **In the diagram of boxplot shows so many outlies. Thats need to be removed from the datasets. Below some of the price of outlier has been replaced with mean value of price.**

# %%
median = housing.price.median()
max_threshold = housing.price.quantile(.995)
max_threshold
# Out:
# 2400000.0

# %%
#housing[housing.price >max_threshold]

# %%
housing["price"] = np.where(housing["price"] > max_threshold, median,housing['price'])

# %%
median1 = housing.price_sqliving.median()
max_threshold1 = housing.price_sqliving.quantile(.9995)
max_threshold1
# Out:
# 1824.3844149999627

# %%
housing["price_sqliving"] = np.where(housing["price_sqliving"] > max_threshold1, median1,housing['price_sqliving'])

# %%
housing.corr()['price'].sort_values()
# Out:
# yr_renovated     -0.045741
# age              -0.027803
# yr_built          0.027803
# condition         0.048729
# sqft_lot          0.085966
# waterfront        0.102228
# floors            0.265612
# sqft_basement     0.273262
# bedrooms          0.317431
# view              0.333020
# bathrooms         0.481381
# sqft_above        0.540050
# price_sqliving    0.545406
# sqft_living       0.615076
# price             1.000000
# Name: price, dtype: float64

# %%
housing.corr()['sqft_living'].sort_values()
# Out:
# age              -0.287775
# yr_renovated     -0.122817
# price_sqliving   -0.110510
# condition        -0.062826
# waterfront        0.117616
# sqft_lot          0.210538
# yr_built          0.287775
# view              0.311009
# floors            0.344850
# sqft_basement     0.447206
# bedrooms          0.594884
# price             0.615076
# bathrooms         0.761154
# sqft_above        0.876443
# sqft_living       1.000000
# Name: sqft_living, dtype: float64

# %%
plt.figure(figsize = (10,5))
sns.boxplot( x= 'price' , data= housing)
# Out:
# <AxesSubplot:xlabel='price'>

# %%
plt.figure(figsize = (10,5))
sns.boxplot( x= 'price_sqliving' , data= housing)
# Out:
# <AxesSubplot:xlabel='price_sqliving'>

# %% [markdown]
# ### price distribustion

# %%
sns.histplot(housing.price)
# Out:
# <AxesSubplot:xlabel='price', ylabel='Count'>

# %% [markdown]
# ## Location and Price

# %%
a4_dims = (12.7, 4.27)
housing.groupby('city').price.mean().sort_values().plot.bar(figsize=a4_dims)
plt.show()

# %%
a4_dims = (12.7, 4.27)
housing.groupby('city').sqft_living.mean().sort_values().plot.bar(figsize=a4_dims)
plt.show()

# %% [markdown]
# ## timeframe and other variables

# %%
sns.histplot(housing.yr_built)
# Out:
# <AxesSubplot:xlabel='yr_built', ylabel='Count'>

# %%
housing.groupby('renovated').price.mean()
# Out:
# renovated
# no     543989.031666
# yes    514581.613796
# Name: price, dtype: float64

# %%
housing.groupby('renovated').price_sqliving.mean().plot.bar()
# Out:
# <AxesSubplot:xlabel='renovated'>

# %%
age_price= housing.groupby('age').price_sqliving.mean().reset_index()
sns.lineplot(x='age',y='price_sqliving', data=age_price)
# Out:
# <AxesSubplot:xlabel='age', ylabel='price_sqliving'>

# %% [markdown]
# ## Corrlation between price and area

# %%
plt.figure(figsize = (10,5))
sns.scatterplot(x= 'sqft_living', y ='price', data= housing)
# Out:
# <AxesSubplot:xlabel='sqft_living', ylabel='price'>

# %%
plt.figure(figsize = (10,5))
sns.scatterplot(x= 'sqft_above', y ='price', data= housing)
# Out:
# <AxesSubplot:xlabel='sqft_above', ylabel='price'>

# %% [markdown]
# ## Floor, Bedrooms , Bathroom

# %%
sns.barplot(x= 'floors', y ='price', data= housing)
# Out:
# <AxesSubplot:xlabel='floors', ylabel='price'>

# %%
a4_dims = (6.7, 3.27)
housing.groupby('floors').price_sqliving.mean().plot.bar(figsize=a4_dims)
plt.show()

# %%
sns.barplot(x= 'bedrooms', y ='price', data= housing)
# Out:
# <AxesSubplot:xlabel='bedrooms', ylabel='price'>

# %%
housing.groupby('bedrooms').price.mean().plot.bar()
# Out:
# <AxesSubplot:xlabel='bedrooms'>

# %%
housing[housing['bedrooms']== 0]
# Out:
#                      date      price  bedrooms  bathrooms  sqft_living  \
# 2365  2014-06-12 00:00:00  1095000.0       0.0        0.0         3064
# 3209  2014-06-24 00:00:00  1295648.0       0.0        0.0         4810
#
#       sqft_lot  floors  waterfront  view  condition  ...  sqft_basement  \
# 2365      4764     3.5           0     2          3  ...              0
# 3209     28008     2.0           0     0          3  ...              0
#
#       yr_built  yr_renovated            street     city  statezip country  \
# 2365      1990          2009     814 E Howe St  Seattle  WA 98102     USA
# 3209      1990          2009  20418 NE 64th Pl  Redmond  WA 98053     USA
#
#      renovated age  price_sqliving
# 2365       yes  24          357.38
# 3209       yes  24          269.37
#
# [2 rows x 21 columns]

# %%
housing[housing['bedrooms']== 9]
# Out:
#                     date     price  bedrooms  bathrooms  sqft_living  \
# 241  2014-05-07 00:00:00  599999.0       9.0        4.5         3830
#
#      sqft_lot  floors  waterfront  view  condition  ...  sqft_basement  \
# 241      6988     2.5           0     0          3  ...           1380
#
#      yr_built  yr_renovated               street     city  statezip country  \
# 241      1938          2003  8809 Densmore Ave N  Seattle  WA 98103     USA
#
#     renovated age  price_sqliving
# 241       yes  76          156.66
#
# [1 rows x 21 columns]

# %%
plt.figure(figsize = (13,4))
sns.barplot(x= 'bathrooms', y ='price', data= housing)
# Out:
# <AxesSubplot:xlabel='bathrooms', ylabel='price'>

# %% [markdown]
# ## Other facilities

# %%
sns.barplot(x= 'view', y ='price', hue='waterfront' ,data= housing)
# Out:
# <AxesSubplot:xlabel='view', ylabel='price'>

# %%
sns.barplot(x= 'waterfront', y ='price',hue='condition', data= housing)
# Out:
# <AxesSubplot:xlabel='waterfront', ylabel='price'>

# %%
housing.groupby('condition').price.mean().plot.bar()
# Out:
# <AxesSubplot:xlabel='condition'>

# %%
sns.catplot(x= 'view' , hue= 'waterfront',
            kind= 'count', data= housing)
